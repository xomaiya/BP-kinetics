# %%
# %load_ext autoreload
# %autoreload 2

# %%
from weiwlets import *
from draws import *
import pywt
plt.rcParams.update({'font.size': 25})

# %%
Iext = 0.5 # возбуждающий импульс на пирамидальную клетку (P)
G = 0.5 # проводимость мембран -- определяют относительный вклад клетки в динамику ансамбля
Eex = 0 # напряжение на выходной клетке (P) -- для активаторной, возбуждающей клетки
Ein = -5 # напряжение на входной клетке (B) -- для ингибиторной, тормозящей клетки
eps = 0.3 # временной масштаб осцилляций (отношение быстрой переменной к медленной)
a = 0.5 # параметры кинетики суммарного ионного тока u
b = 0.8 # параметры кинетики суммарного ионного тока u
A = 1 # синаптический параметр
Bpb = 0.19 # синаптический параметр
Bbpmin = 0.02 # синаптический параметр
Bbpmax = 0.12 # синаптический параметр
vsl = 0.1 # синаптический параметр (открытие синапсов быстрее чем закрытие)

args1 = (Iext, G, Ein, Eex, eps, a, b, A, Bpb, Bbpmin, Bbpmax, vsl)
signal_draw1(args1, vp0=0, vb0=0, up0=0, ub0=0, sbp0=0, spb0=0, ts=2000, nt=2**13)

sol = calcODE1(args1, 0, 0, 0, 0, 0, 0, ts=2000, nt=2**13)
t = np.linspace(0, 2000, 2**13)

vp = sol[:, 0]
scale = np.linspace(0, 60, 101)
vp = sAnalytics(vp)

res = fftMorlet(t, vp, scale, np.pi)

plt.figure(figsize=(20, 10))
plt.imshow(np.abs(res), aspect='auto', origin='lower')

# %%
print(args)
phase_portrait(args, 0, 0, 0, 0 , 0, 0, 2000, nt=2**13)
# Out:
# (0.5, 0.5, -5, 0, 0.3, 0.5, 0.8, 1, 0.19, 0.06, 0.1, 0.1)
# /home/xomaiya/Нейронауки/BP_kinetics/draws.py:16: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(np.abs(res), vp/t, 'g')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-172-060c1c8a68ad> in <module>
#       1 print(args)
# ----> 2 phase_portrait(args, 0, 0, 0, 0 , 0, 0, 2000, nt=2**13)
#
# ~/Нейронауки/BP_kinetics/draws.py in phase_portrait(args, vp0, vb0, up0, ub0, sbp0, spb0, ts, nt)
#      14     res = fftMorlet(t, vp, scale, np.pi)
#      15     plt.figure(figsize=(10, 10))
# ---> 16     plt.plot(np.abs(res), abs(vp/t) , 'g')
#      17
#      18     plt.xlabel('x')
#
# ~/.conda/envs/ml/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# ~/.conda/envs/ml/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# ~/.conda/envs/ml/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# ~/.conda/envs/ml/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# ~/.conda/envs/ml/lib/python3.7/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (101, 8192) and (8192,)

# %%
Iext = 0.5 # возбуждающий импульс на пирамидальную клетку (P)
G = 0.5 # проводимость мембран -- определяют относительный вклад клетки в динамику ансамбля
Eex = 0 # напряжение на выходной клетке (P) -- для активаторной, возбуждающей клетки
Ein = -5 # напряжение на входной клетке (B) -- для ингибиторной, тормозящей клетки
eps = 0.3 # временной масштаб осцилляций (отношение быстрой переменной к медленной)
a = 0.5 # параметры кинетики суммарного ионного тока u
b = 0.8 # параметры кинетики суммарного ионного тока u
A = 1 # синаптический параметр
vsl = 0.1 # синаптический параметр (открытие синапсов быстрее чем закрытие)

Bbp = 0.04 # синаптический параметр
Bpbmin = 0.15 # синаптический параметр
Bpbmax = 0.25 # синаптический параметр
args2 = (Iext, G, Ein, Eex, eps, a, b, A, Bpbmin, Bpbmax, Bbp, vsl)
signal_draw2(args2, vp0=0, vb0=0, up0=0, ub0=0, sbp0=0, spb0=0, ts=2000, nt=2**14)

sol = calcODE2(args2, 0, 0, 0, 0, 0, 0, ts=2000, nt=2**14)
t = np.linspace(0, 2000, 2**14)

vp = sol[:, 0]
scale = np.linspace(0, 60, 101)
vp = sAnalytics(vp)

res = fftMorlet(t, vp, scale, np.pi)

plt.figure(figsize=(20, 10))
plt.imshow(np.abs(res), aspect='auto', origin='lower')

# %%
Iext = 0.5 # возбуждающий импульс на пирамидальную клетку (P)
G = 0.5 # проводимость мембран -- определяют относительный вклад клетки в динамику ансамбля
Eex = 0 # напряжение на выходной клетке (P) -- для активаторной, возбуждающей клетки
Ein = -5 # напряжение на входной клетке (B) -- для ингибиторной, тормозящей клетки
eps = 0.3 # временной масштаб осцилляций (отношение быстрой переменной к медленной)
a = 0.5 # параметры кинетики суммарного ионного тока u
b = 0.8 # параметры кинетики суммарного ионного тока u
A = 1 # синаптический параметр
vsl = 0.1 # синаптический параметр (открытие синапсов быстрее чем закрытие)

Bbp = 0.06 # синаптический параметр
Bpbmin = 0.15 # синаптический параметр
Bpbmax = 0.25 # синаптический параметр
args2 = (Iext, G, Ein, Eex, eps, a, b, A, Bpbmin, Bpbmax, Bbp, vsl)
signal_draw2(args2, vp0=0, vb0=0, up0=0, ub0=0, sbp0=0, spb0=0, ts=2000, nt=2**13)

sol = calcODE2(args2, 0, 0, 0, 0, 0, 0, ts=2000, nt=2**13)
t = np.linspace(0, 2000, 2**13)

vp = sol[:, 0]
scale = np.linspace(0, 60, 101)
vp = sAnalytics(vp)

res = fftMorlet(t, vp, scale, np.pi)

plt.figure(figsize=(20, 10))
plt.imshow(np.abs(res), aspect='auto', origin='lower')

# %%
Iext = 0.5 # возбуждающий импульс на пирамидальную клетку (P)
G = 0.5 # проводимость мембран -- определяют относительный вклад клетки в динамику ансамбля
Eex = 0 # напряжение на выходной клетке (P) -- для активаторной, возбуждающей клетки
Ein = -5 # напряжение на входной клетке (B) -- для ингибиторной, тормозящей клетки
eps = 0.3 # временной масштаб осцилляций (отношение быстрой переменной к медленной)
a = 0.5 # параметры кинетики суммарного ионного тока u
b = 0.8 # параметры кинетики суммарного ионного тока u
A = 1 # синаптический параметр
vsl = 0.1 # синаптический параметр (открытие синапсов быстрее чем закрытие)

Bbp = 0.08 # синаптический параметр
Bpbmin = 0.15 # синаптический параметр
Bpbmax = 0.25 # синаптический параметр
args2 = (Iext, G, Ein, Eex, eps, a, b, A, Bpbmin, Bpbmax, Bbp, vsl)
signal_draw2(args2, vp0=0, vb0=0, up0=0, ub0=0, sbp0=0, spb0=0, ts=2000, nt=2**13)

sol = calcODE2(args2, 0, 0, 0, 0, 0, 0, ts=2000, nt=2**13)
t = np.linspace(0, 2000, 2**13)

vp = sol[:, 0]
scale = np.linspace(0, 60, 101)
vp = sAnalytics(vp)

res = fftMorlet(t, vp, scale, np.pi)

plt.figure(figsize=(20, 10))
plt.imshow(np.abs(res), aspect='auto', origin='lower')

# %%
Iext = 0.5 # возбуждающий импульс на пирамидальную клетку (P)
G = 0.5 # проводимость мембран -- определяют относительный вклад клетки в динамику ансамбля
Eex = 0 # напряжение на выходной клетке (P) -- для активаторной, возбуждающей клетки
Ein = -5 # напряжение на входной клетке (B) -- для ингибиторной, тормозящей клетки
eps = 0.3 # временной масштаб осцилляций (отношение быстрой переменной к медленной)
a = 0.5 # параметры кинетики суммарного ионного тока u
b = 0.8 # параметры кинетики суммарного ионного тока u
A = 1 # синаптический параметр
vsl = 0.1 # синаптический параметр (открытие синапсов быстрее чем закрытие)

Bbp = 0.1 # синаптический параметр
Bpbmin = 0.20 # синаптический параметр
Bpbmax = 0.205 # синаптический параметр
args2 = (Iext, G, Ein, Eex, eps, a, b, A, Bpbmin, Bpbmax, Bbp, vsl)
signal_draw2(args2, vp0=0, vb0=0, up0=0, ub0=0, sbp0=0, spb0=0, ts=2000, nt=2**14)

sol = calcODE2(args2, 0, 0, 0, 0, 0, 0, ts=2000, nt=2**14)
t = np.linspace(0, 2000, 2**14)

vp = sol[:, 0]
scale = np.linspace(0, 60, 101)
vp = sAnalytics(vp)

res = fftMorlet(t, vp, scale, np.pi)

plt.figure(figsize=(20, 10))
plt.imshow(np.abs(res), aspect='auto', origin='lower')

# %%
1/ D докторской глава2
2. С уменьшением шага по параметру поисследовать область переходов на 0.08 и 0.1, построить вейвлеты
при варьировании ну надо брать отрицательные потенциалы (V=-2;2), а ток посмотреть положительный
3. Посмотртье на сосуществующие аттракторы (начальные условия поварьировать) построить графики
4. Отослать файл с гистерезисом
